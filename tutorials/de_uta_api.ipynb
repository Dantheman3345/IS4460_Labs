# %% [markdown]
# <a href="https://colab.research.google.com/github/Dantheman3345/IS4460_Labs/blob/main/tutorials/de_uta_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Get a UTA token
#
# https://developer.rideuta.com/Registration.aspx

# %%
#!pip install xmltodict

# %%
from google.colab import userdata
import xmltodict

uta_secret = userdata.get('uta')

# %%
route = "703"

# %%
import requests

url = f'http://api.rideuta.com/SIRI/SIRI.svc/VehicleMonitor/ByRoute?route={route}&onwardcalls=true&usertoken={uta_secret}'
response = requests.get(url)
print(response.text)

xml_dict = xmltodict.parse(response.text)
# Out:
# <?xml version="1.0" encoding="utf-8"?><Siri version="1.3" xmlns="http://www.siri.org.uk/siri"><ResponseTimestamp>2024-03-18T13:01:07.4949527-06:00</ResponseTimestamp><VehicleMonitoringDelivery version="1.3"><ResponseTimestamp>2024-03-18T13:01:07.4949527-06:00</ResponseTimestamp><ValidUntil>2024-03-18T13:01:17.4949527-06:00</ValidUntil><VehicleActivity><RecordedAtTime>2024-03-18T13:01:07.4949527-06:00</RecordedAtTime><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef/><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>0</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>0</OriginRef><DestinationRef>0</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-112.0202925</Longitude><Latitude>40.550404166666667</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400673</CourseOfJourneyRef><VehicleRef>1106</VehicleRef><Extensions><LastGPSFix>2024-03-18T13:01:03.36</LastGPSFix><Scheduled>False</Scheduled><Bearing>143.5</Bearing><Speed>34.869240000000005</Speed><DestinationName/></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef>TO MEDICAL</DirectionRef><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>5281607</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>TX101715</OriginRef><DestinationRef>TX127252</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-111.87251633333334</Longitude><Latitude>40.760650666666663</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400951</CourseOfJourneyRef><VehicleRef>1114</VehicleRef><Extensions><LastGPSFix>2024-03-18T13:01:02.393</LastGPSFix><Scheduled>False</Scheduled><Bearing>89.4</Bearing><Speed>0</Speed><DestinationName>University Medical</DestinationName></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef/><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>0</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>0</OriginRef><DestinationRef>0</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-111.87355066666667</Longitude><Latitude>40.760719</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400885</CourseOfJourneyRef><VehicleRef>1120</VehicleRef><Extensions><LastGPSFix>2024-03-18T13:01:07.33</LastGPSFix><Scheduled>False</Scheduled><Bearing>267.6</Bearing><Speed>0</Speed><DestinationName/></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef/><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>0</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>0</OriginRef><DestinationRef>0</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-112.0038955</Longitude><Latitude>40.581639666666668</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400820</CourseOfJourneyRef><VehicleRef>1128</VehicleRef><Extensions><LastGPSFix>2024-03-18T13:01:07.03</LastGPSFix><Scheduled>False</Scheduled><Bearing>56.7</Bearing><Speed>0</Speed><DestinationName/></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef>TO MEDICAL</DirectionRef><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>5281619</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>TX101715</OriginRef><DestinationRef>TX127252</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-112.02522</Longitude><Latitude>40.55624</Latitude></VehicleLocatio ...

# %%
xml_dict['Siri']['VehicleMonitoringDelivery']['VehicleActivity']['MonitoredVehicleJourney']
# Out:
# [{'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-112.0202925',
#    'Latitude': '40.550404166666667'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400673',
#   'VehicleRef': '1106',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:03.36',
#    'Scheduled': 'False',
#    'Bearing': '143.5',
#    'Speed': '34.869240000000005',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': 'TO MEDICAL',
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '5281607'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': 'TX101715',
#   'DestinationRef': 'TX127252',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.87251633333334',
#    'Latitude': '40.760650666666663'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400951',
#   'VehicleRef': '1114',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:02.393',
#    'Scheduled': 'False',
#    'Bearing': '89.4',
#    'Speed': '0',
#    'DestinationName': 'University Medical'}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.87355066666667',
#    'Latitude': '40.760719'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400885',
#   'VehicleRef': '1120',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:07.33',
#    'Scheduled': 'False',
#    'Bearing': '267.6',
#    'Speed': '0',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-112.0038955',
#    'Latitude': '40.581639666666668'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400820',
#   'VehicleRef': '1128',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:07.03',
#    'Scheduled': 'False',
#    'Bearing': '56.7',
#    'Speed': '0',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': 'TO MEDICAL',
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '5281619'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': 'TX101715',
#   'DestinationRef': 'TX127252',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-112.02522', 'Latitude': '40.55624'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '10100',
#   'VehicleRef': '1128',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:32.217',
#    'Scheduled': 'False',
#    'Bearing': '144.4',
#    'Speed': '38.563308',
#    'DestinationName': 'University Medical'}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.91586316666667',
#    'Latitude': '40.6171035'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400881',
#   'VehicleRef': '1134',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:04.283',
#    'Scheduled': 'False',
#    'Bearing': '263.4',
#    'Speed': '16.91676',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': 'TO MEDICAL',
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '5281618'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': 'TX101715',
#   'DestinationRef': 'TX127252',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.904468', 'Latitude': '40.630387'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '414964',
#   'VehicleRef': '1152',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:06.75',
#    'Scheduled': 'False',
#    'Bearing': '25.1',
#    'Speed': '28.677936000000003',
#    'DestinationName': 'University Medical'}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.89680433333334',
#    'Latitude': '40.724619'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400823',
#   'VehicleRef': '1154',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:04.67',
#    'Scheduled': 'False',
#    'Bearing': '0.2',
#    'Speed': '0',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.89700916666666',
#    'Latitude': '40.69962533333333'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400808',
#   'VehicleRef': '1169',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:06.813',
#    'Scheduled': 'False',
#    'Bearing': '179.4',
#    'Speed': '31.992240000000002',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.838622', 'Latitude': '40.76941'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400865',
#   'VehicleRef': '1173',
#   'Extensions': {'LastGPSFix': '2024-03-18T13:01:07.437',
#    'Scheduled': 'False',
#    'Bearing': '199.1',
#    'Speed': '0',
#    'DestinationName': None}}]

# %%
import pandas as pd

df = pd.DataFrame(xml_dict['Siri']['VehicleMonitoringDelivery']['VehicleActivity']['MonitoredVehicleJourney'])
df
# Out:
#   LineRef DirectionRef                            FramedVehicleJourneyRef  \
# 0     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 1     703   TO MEDICAL  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 2     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 3     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 4     703   TO MEDICAL  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 5     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 6     703   TO MEDICAL  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 7     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 8     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 9     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
#
#   PublishedLineName OriginRef DestinationRef Monitored  \
# 0          RED LINE         0              0      True
# 1          RED LINE  TX101715       TX127252      True
# 2          RED LINE         0              0      True
# 3          RED LINE         0              0      True
# 4          RED LINE  TX101715       TX127252      True
# 5          RED LINE         0              0      True
# 6          RED LINE  TX101715       TX127252      True
# 7          RED LINE         0              0      True
# 8          RED LINE         0              0      True
# 9          RED LINE         0              0      True
#
#                                      VehicleLocation ProgressRate  \
# 0  {'Longitude': '-112.0202925', 'Latitude': '40....            1
# 1  {'Longitude': '-111.87251633333334', 'Latitude...            1
# 2  {'Longitude': '-111.87355066666667', 'Latitude...            1
# 3  {'Longitude': '-112.0038955', 'Latitude': '40....            1
# 4  {'Longitude': '-112.02522', 'Latitude': '40.55...            1
# 5  {'Longitude': '-111.91586316666667', 'Latitude...            1
# 6  {'Longitude': '-111.904468', 'Latitude': '40.6...            1
# 7  {'Longitude': '-111.89680433333334', 'Latitude...            1
# 8  {'Longitude': '-111.89700916666666', 'Latitude...            1
# 9  {'Longitude': '-111.838622', 'Latitude': '40.7...            1
#
#   CourseOfJourneyRef VehicleRef  \
# 0             400673       1106
# 1             400951       1114
# 2             400885       1120
# 3             400820       1128
# 4              10100       1128
# 5             400881       1134
# 6             414964       1152
# 7             400823       1154
# 8             400808       1169
# 9             400865       1173
#
#                                           Extensions
# 0  {'LastGPSFix': '2024-03-18T13:01:03.36', 'Sche...
# 1  {'LastGPSFix': '2024-03-18T13:01:02.393', 'Sch...
# 2  {'LastGPSFix': '2024-03-18T13:01:07.33', 'Sche...
# 3  {'LastGPSFix': '2024-03-18T13:01:07.03', 'Sche...
# 4  {'LastGPSFix': '2024-03-18T12:56:32.217', 'Sch...
# 5  {'LastGPSFix': '2024-03-18T13:01:04.283', 'Sch...
# 6  {'LastGPSFix': '2024-03-18T13:01:06.75', 'Sche...
# 7  {'LastGPSFix': '2024-03-18T13:01:04.67', 'Sche...
# 8  {'LastGPSFix': '2024-03-18T13:01:06.813', 'Sch...
# 9  {'LastGPSFix': '2024-03-18T13:01:07.437', 'Sch...

# %%
location_df = df[['VehicleLocation']]
location_df
# Out:
#                                      VehicleLocation
# 0  {'Longitude': '-112.0202925', 'Latitude': '40....
# 1  {'Longitude': '-111.87251633333334', 'Latitude...
# 2  {'Longitude': '-111.87355066666667', 'Latitude...
# 3  {'Longitude': '-112.0038955', 'Latitude': '40....
# 4  {'Longitude': '-112.02522', 'Latitude': '40.55...
# 5  {'Longitude': '-111.91586316666667', 'Latitude...
# 6  {'Longitude': '-111.904468', 'Latitude': '40.6...
# 7  {'Longitude': '-111.89680433333334', 'Latitude...
# 8  {'Longitude': '-111.89700916666666', 'Latitude...
# 9  {'Longitude': '-111.838622', 'Latitude': '40.7...

# %%
# prompt: convert dict to columns in location_df

import pandas as pd
location_df = pd.json_normalize(location_df['VehicleLocation'])
location_df
# Out:
#              Longitude            Latitude
# 0         -112.0202925  40.550404166666667
# 1  -111.87251633333334  40.760650666666663
# 2  -111.87355066666667           40.760719
# 3         -112.0038955  40.581639666666668
# 4           -112.02522            40.55624
# 5  -111.91586316666667          40.6171035
# 6          -111.904468           40.630387
# 7  -111.89680433333334           40.724619
# 8  -111.89700916666666   40.69962533333333
# 9          -111.838622            40.76941

# %%
def get_locations():
    url = f'http://api.rideuta.com/SIRI/SIRI.svc/VehicleMonitor/ByRoute?route={route}&onwardcalls=true&usertoken={uta_secret}'
    response = requests.get(url)
    xml_dict = xmltodict.parse(response.text)
    df = pd.DataFrame(xml_dict['Siri']['VehicleMonitoringDelivery']['VehicleActivity']['MonitoredVehicleJourney'])
    location_df = pd.json_normalize(df['VehicleLocation'])
    return location_df

# %%
import folium

# Create a base map centered at the specified latitude and longitude.
map = folium.Map(location=[40.7128, -111.85], zoom_start=12)

location_df = get_locations()

# Add a marker to the map at the specified latitude and longitude.
for (lat, lon) in zip(location_df['Latitude'], location_df['Longitude']):
    folium.Marker([lat, lon], popup='UTA Bus Stop').add_to(map)

# Display the map.
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c573447f7cd79111d076c11a5a2dc566 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c573447f7cd79111d076c11a5a2dc566&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c573447f7cd79111d076c11a5a2dc566 = L.map(
#                 &quot;map_c573447f7cd79111d076c11a5a2dc566&quot;,
#                 {
#                     center: [40.7128, -111.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_935c436a094b4614d116ce513a01a514 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c573447f7cd79111d076c11a5a2dc566);
#
#
#             var marker_4b950f9a32739bab7678657d82e2adb8 = L.marker(
#                 [40.54682, -112.016627],
#                 {}
#             ).addTo(map_c573447f7cd79111d076c11a5a2dc566);
#
#
#         var popup_908c2780bf20f6145286a83c58d69850 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4db5660414a3f76397e878bcde58dbe = $(`&lt;div id=&quot;html_b4db5660414a3f76397e878bcde58dbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_908c2780bf20f6145286a83c58d69850.setContent(html_b4db5660414a3f76397e878bcde58dbe);
#
#
#
#         marker_4b950f9a32739bab7678657d82e2adb8.bindPopup(popup_908c2780bf20f6145286a83c58d69850)
#         ;
#
#
#
#
#             var marker_a71fa3d92313775333addc50560af74f = L.marker(
#                 [40.76067416666667, -111.86829816666666],
#                 {}
#             ).addTo(map_c573447f7cd79111d076c11a5a2dc566);
#
#
#         var popup_28e2cb340658de4bf322cbfcfaa9daaf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7acbbac9efaf97297867fa5b22ebf2d7 = $(`&lt;div id=&quot;html_7acbbac9efaf97297867fa5b22ebf2d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_28e2cb340658de4bf322cbfcfaa9daaf.setContent(html_7acbbac9efaf97297867fa5b22ebf2d7);
#
#
#
#         marker_a71fa3d92313775333addc50560af74f.bindPopup(popup_28e2cb340658de4bf322cbfcfaa9daaf)
#         ;
#
#
#
#
#             var marker_a574a1f31c34c1b98203a83c9bf2ce9a = L.marker(
#                 [40.760718, -111.87763916666667],
#                 {}
#             ).addTo(map_c573447f7cd79111d076c11a5a2dc566);
#
#
#         var popup_9f9568ee14e3a1e0e846f7a43395c2c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_138eaf45178b808e5990213cf4a255d9 = $(`&lt;div id=&quot;html_138eaf45178b808e5990213cf4a255d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_9f9568ee14e3a1e0e846f7a43395c2c0.setContent(html_138eaf45178b808e5990213cf4a255d9);
#
#
#
#         marker_a574a1f31c34c1b98203a83c9bf2ce9a.bindPopup(popup_9f9568ee14e3a1e0e846f7a43395c2c0)
#         ;
#
#
#
#
#             var marker_5ac7511863d2190944cfaf966f8c1d09 = L.marker(
#                 [40.581902166666666, -112.00336033333333],
#                 {}
#             ).addTo(map_c573447f7cd79111d076c11a5a2dc566);
#
#
#         var popup_ce676e00d68c45b90ceb0b253969cd5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a59a92a7a0809004ba20e34fd441816 = $(`&lt;div id=&quot;html_5a59a92a7a0809004ba20e34fd441816&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_ce676e00d68c45b90ceb0b253969cd5e.setContent(html_5a59a92a7a0809004ba20e34fd441816);
#
#
#
#         marker_5ac7511863d2190944cfaf966f8c1d09.bindPopup(popup_ce676e00d68c45b90ceb0b253969cd5e)
#         ;
#
#
#
#
#             var marker_77ec20f6ca2f977040f44fd9d32c0c95 = L.marker(
#                 [40.614017, -111.921412],
#                 {}
#             ).addTo(map_c573447f7cd79111d076c11a5a2dc566);
#
#
#         var popup_09388924fc8af0404e49f6fd19973148 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53dec59176fb763ef4048c596785bc2b = $(`&lt;div id=&quot;html_53dec59176fb763ef4048c596785bc2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_09388924fc8af0404e49f6fd19973148.setContent(html_53dec59176fb763ef4048c596785bc2b);
#
#
#
#         marker_77ec20f6ca2f977040f44fd9d32c0c95.bindPopup(popup_09388924fc8af0404e49f6fd19973148)
#         ;
#
#
#
#
#             var marker_1be4edd3ec57664e2ebfd43d1e023c36 = L.marker(
